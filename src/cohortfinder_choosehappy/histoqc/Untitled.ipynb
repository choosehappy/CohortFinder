# %%
import pandas as pd
import glob
import shutil
import os
import cv2

# %%
df=pd.read_csv('deleteme.csv')
df
# Out:
#                                                folder  Unnamed: 1  Unnamed: 2  \
# 0   TCGA-AD-A5EJ-01Z-00-DX1.FA56CEAF-8B70-45EF-A2C...         NaN         NaN
# 1   TCGA-F4-6855-01Z-00-DX1.41ed5985-be19-4dce-aab...         NaN         NaN
# 2   TCGA-G4-6306-01Z-00-DX1.962227ca-b0d6-4cf4-afe...         NaN         NaN
# 3   TCGA-A6-5662-01Z-00-DX1.82569684-1c31-4346-af9...         NaN         NaN
# 4   TCGA-AA-3841-01Z-00-DX1.10f98d09-027f-4495-9ad...         NaN         NaN
# 5   TCGA-AA-A00E-01Z-00-DX1.ABFCAF2D-287A-445F-9F3...         NaN         NaN
# 6   TCGA-AD-6888-01Z-00-DX1.47AE342C-4577-4D8B-904...         NaN         NaN
# 7   TCGA-AY-A69D-01Z-00-DX1.94582A46-7470-4265-837...         NaN         NaN
# 8   TCGA-A6-5659-01Z-00-DX1.c671806f-013e-4d99-984...         NaN         NaN
# 9   TCGA-AA-3548-01Z-00-DX1.41949ab5-79f2-4729-9d5...         NaN         NaN
# 10  TCGA-CM-6166-01Z-00-DX1.52eaa124-7ab5-4aaf-b07...         NaN         NaN
# ...

# %%
foldernames = df['folder']

# %%
for folder in foldernames:
#     print(folder)
#     os.mkdir(folder)
    thumbnail = glob.glob(f'/Volumes/EXTERNAL_USB/Cohortfinder/CF_COAD/2023/Adenocarcinoma_NOS_Apr_25_REMOVE_DUPLICATE_SLIDES/HISTOQC_COAD/{folder}/*thumb*small*')[0]
    shutil.copy(thumbnail,folder)

# %%
files = glob.glob('*/*.png')
for file in files:
    print(file)
    img = cv2.imread(file)
    img = cv2.resize(img,(0,0),fx=.5,fy=.5)
    cv2.imwrite(file,img)
# Out:
# TCGA-AA-3848-01Z-00-DX1.bb018b1c-7748-4865-b00f-42edc35b5047.svs/TCGA-AA-3848-01Z-00-DX1.bb018b1c-7748-4865-b00f-42edc35b5047.svs_thumb.png
# TCGA-AA-3562-01Z-00-DX1.e07893e6-646d-41b5-be51-9c19d51f6743.svs/TCGA-AA-3562-01Z-00-DX1.e07893e6-646d-41b5-be51-9c19d51f6743.svs_thumb.png
# TCGA-AA-3520-01Z-00-DX1.3e2b41c2-eb21-4f68-8946-92b59cc1f969.svs/TCGA-AA-3520-01Z-00-DX1.3e2b41c2-eb21-4f68-8946-92b59cc1f969.svs_thumb.png
# TCGA-AA-3841-01Z-00-DX1.10f98d09-027f-4495-9ad8-7c8dc49a07d7.svs/TCGA-AA-3841-01Z-00-DX1.10f98d09-027f-4495-9ad8-7c8dc49a07d7.svs_thumb.png
# TCGA-CM-6166-01Z-00-DX1.52eaa124-7ab5-4aaf-b074-7f89a4c53804.svs/TCGA-CM-6166-01Z-00-DX1.52eaa124-7ab5-4aaf-b074-7f89a4c53804.svs_thumb.png
# TCGA-CA-5256-01Z-00-DX1.67cc2ca1-40df-4e76-be88-dfd93e20e017.svs/TCGA-CA-5256-01Z-00-DX1.67cc2ca1-40df-4e76-be88-dfd93e20e017.svs_thumb.png
# TCGA-F4-6854-01Z-00-DX1.a4d18769-1632-41e4-b49d-4a88d36e21ab.svs/TCGA-F4-6854-01Z-00-DX1.a4d18769-1632-41e4-b49d-4a88d36e21ab.svs_thumb.png
# ...
